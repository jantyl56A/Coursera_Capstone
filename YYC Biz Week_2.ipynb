# %% [markdown]
# # CAPSTONE PROJECT - BEER AVAILABILITY IN CALGARY, CANADA - Week 2

# %% [markdown]
# ## 1. Introduction:
# Well-known for natural beauty of the close-by Rocky Mountains, the City of Calgary, Alberta, Canada, has also gone through transformation in terms of availability of beer in the last three decades. Historically, distribution and access to alcohol was limited and controlled by the government. In 1993, there were only 202 retail locations, so-called Alberta Liquor Control Board (ALCB) Liquor Stores in the entire province (Wikipedia) and many restaurants did not sell alcohol on Sundays. In 1993, following a provincial election, all ALCB liquor stores were quickly privatized and the industry experienced a major boom. The decision was controversial, due to its impact on both employment and alcohol availability. On the one hand, some claim that the Alberta government lost CAD 5 billion in the first 25 years following the privatization and yet the case of beer is on average CAD 10 more expensive than in government-owned beer stores in Ontario (https://www.beerfactsontario.ca/albertafacts). Others claim that the privatization was a resounding success, the claims of foregone government revenues are incorrect, prices are fine and the selection is much better following the privatization (https://www.fraserinstitute.org/article/success-albertas-liquor-store-privatization-lesson-other-provinces). It is, however, also true that, "In recent years disorderly conduct at and near licensed establishments was identified as a growing problem, particularly in the major cities. The province's economic boom and the resulting affluence of its youth were identified as the root cause of the increase in binge drinking" (https://en.wikipedia.org/wiki/Alberta_Gaming,_Liquor_and_Cannabis_Commission). The objective of this Capstone Project is to explore Calgary communities to establish how available beer is in Calgary today, both in retail venues and in restaurants.
#
# To achieve the Capstone Project's objective, then, information available from public sources will be collected and analysis of Calgary communities performed, identifying establishments holding Alcohol Beverage Sales License and Liquor Stores. This information will be pre-processed and subjected to clustering to identify and rank Calgary regions in terms of beer availability. This exercise does not intend to explore and rank quality of the beverages sold or served, as these preferences are highly subjective.
#
# It is expected, that the downtown and University of Calgary areas are best-served in this respect, while bedroom communities in the suburbs are not. In addition, the results should provide the newcomer to Calgary with one bit of information that may be relevant when making the decision as to which community suits their needs best.

# %% [markdown]
# ## 2. Data Section
# Data Link: https://data.calgary.ca/Business-and-Economic-Activity/Calgary-Business-Licences/vdjc-pybd/data
#
# The link has been obtained from City of Calgary pages and contains the list of all businesses legally operating in the City.
#
# The dataset contains data about all relevant establishments in all communities of Calgary, including locational information, such as tradename, address, status of Alcohol Beverage Sales license, geographic coordinates, etc. For the purpose of this exercise, i.e., exploring all relevant businesses, the selected dataset is deemed to serve the purpose best, as it can be relied on to contain an exhaustive list of relevant entities.
#
# Following review of the data and some pre-processing, the relevant data has been mapped out to obtain an overall perspective on beer availability in the City. While this overall review indicates the status quo, additional detail has been obtained through clustering.
#
# Initial data obtained from the Business License Register included the following information:
#
#     1. Tradename
#     2. Address
#     3. License Type
#     4. Community
#     5. Status
#     6. Date of Registration
#     7. Address Longitude
#     8. Address Latitude
#
# Folium Maps:
#
# Map of Calgary

# %% [markdown]
# ## 3. Methodology Section
#
# Clustering Approach:
#
# To analyze the data obtained and pre-processed, clustering has been selected as the approach providing the most useful information. Communities with the largest and lowest number of locations have been identified and graphed and mapped out, then, for the purposes clustering, the data has been cleaned and simplified. Eight clusters has been determined as being the optimum and the method used was k-means.

# %% [markdown]
# ## 4. Results Section
#
# Map of Clusters in Calgary
#
#
# List of all locations within clusters in Calgary
#
#
# Ranking the Clusters
#
#
# The Province of Alberta:
#
# Alberta is a province in Western Canada. Its landscape encompasses mountains, prairies, desert badlands and vast coniferous forests. It has more than 600 lakes, and rich mineral deposits. In the west, the Canadian Rocky Mountain Parks have glaciers in the Columbia Icefields. The Waterton Glacier International Peace Park is a biosphere reserve that straddles the southern border with the USA (Wikipedia). Alberta's population was 4.371 million in 2019 (StatCan).
#
# The City of Calgary:
#
# Calgary is a cosmopolitan Alberta city with numerous skyscrapers which owes its rapid growth to its status as the centre of Canada’s oil industry. However, it’s still steeped in the western culture that earned it the nickname “Cowtown,” evident in the Calgary Stampede, its massive July rodeo and festival that grew out of the farming exhibitions once presented here.
#
# Elevation: 1,045 m
# Population: 1.514 million (2020 - www.statista.com)
# Area code(s): 403, 587, 825
#
# Calgary Business Licenses:
# This Capstone project uses  the City of Calgary dataset collection as its prime data gathering source as it contains data on all legally operating businesess in the City and includes the licensed businesses in the City of Calgary. Data fields include: Trade name, Business Location, Creation Date, Status, Licence Type and Community District of the business.

# %% [markdown]
# ## 5. Discussion Section
#
# The objective of this project is to illustrate the impact on the society of changing the rules and provide basic information on the current situation. As mentioned previously, until 1994, there were only 202 liquor stores in the entire province, and, in Calgary, the bar community was represented primarily by "Electric Avenue", four blocks of two dozens of bars on 11 Ave, S.W.
#
# The numbers show clearly that, even though the concept of liquor stores has been kept, deregulation of the industry has led to a boom - there are over 350 liquor stores in Calgary and the number of beer-serving places has gone well over 1,500.

# %% [markdown]
# ## 6. Conclusion Section
#
# In this Capstone project k-means clustering was used to divide the City of Calgary into 8 clusters. The number of entities in clusters varies from 103 (cluster 7) to 756 (cluster 1) venues.
#
# The findings support the assumption that downtown houses the largest number of beer-serving establishments, while the bedroom communities in suburbs have the lowest number of the venues. This conclusion is also relevant for anyone wishing to explore the idea of opening a bar, restaurant or pub. The areas to explore should perhaps include the communities outside downtown and university regions.
#
#
# Future Works:
#
# This Capstone Project could be used to develop a beer map of Calgary with more focus on quality aspect.
#
# Libraries used:
#
# Pandas: To create and manipulate dataframes.
#
# Folium: To visualize the venues and cluster distribution of using interactive leaflet map.
#
# Scikit Learn: To import k-means clustering.
#
# JSON: To handle JSON files.
#
# Geocoder: To retrieve Location Data.
#
# Beautiful Soup and Requests: To scrap and library to handle http requests.
#
# Matplotlib: To plot data.
#
# GitHub Link of Complete Project :

# %%
import numpy as np
import pandas as pd

#Command to install OpenCage Geocoder for fetching Lat and Lng of Neighborhood
# !pip install opencage

#Importing OpenCage Geocoder
from opencage.geocoder import OpenCageGeocode

# use the inline backend to generate the plots within the browser
# %matplotlib inline 

#Importing Matplot lib and associated packages to perform Data Visualisation and Exploratory Data Analysis
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.style.use('ggplot') # optional: for ggplot-like style

# check for latest version of Matplotlib
print ('Matplotlib version: ', mpl.__version__) # >= 2.0.0

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

#Importing folium to visualise Maps and plot based on Lat and Lng
# !conda install -c conda-forge folium=0.5.0 --yes
import folium

#Requests to request web pages by making get requests to FourSquare REST Client
import requests

#To normalise data returned by FourSquare API
from pandas.io.json import json_normalize

#Importing KMeans from SciKit library to Classify neighborhoods into clusters
from sklearn.cluster import KMeans

print('Libraries imported')
# Out:
# Requirement already satisfied: opencage in ./opt/anaconda3/lib/python3.7/site-packages (1.2.1)
# Requirement already satisfied: Requests>=2.2.0 in ./opt/anaconda3/lib/python3.7/site-packages (from opencage) (2.22.0)
# Requirement already satisfied: pyopenssl>=0.15.1 in ./opt/anaconda3/lib/python3.7/site-packages (from opencage) (19.1.0)
# Requirement already satisfied: backoff>=1.10.0 in ./opt/anaconda3/lib/python3.7/site-packages (from opencage) (1.10.0)
# Requirement already satisfied: six>=1.4.0 in ./opt/anaconda3/lib/python3.7/site-packages (from opencage) (1.14.0)
# Requirement already satisfied: idna<2.9,>=2.5 in ./opt/anaconda3/lib/python3.7/site-packages (from Requests>=2.2.0->opencage) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in ./opt/anaconda3/lib/python3.7/site-packages (from Requests>=2.2.0->opencage) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in ./opt/anaconda3/lib/python3.7/site-packages (from Requests>=2.2.0->opencage) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in ./opt/anaconda3/lib/python3.7/site-packages (from Requests>=2.2.0->opencage) (3.0.4)
# Requirement already satisfied: cryptography>=2.8 in ./opt/anaconda3/lib/python3.7/site-packages (from pyopenssl>=0.15.1->opencage) (2.8)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in ./opt/anaconda3/lib/python3.7/site-packages (from cryptography>=2.8->pyopenssl>=0.15.1->opencage) (1.14.0)
# Requirement already satisfied: pycparser in ./opt/anaconda3/lib/python3.7/site-packages (from cffi!=1.11.3,>=1.8->cryptography>=2.8->pyopenssl>=0.15.1->opencage) (2.19)
# Matplotlib version:  3.1.3
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Libraries imported

# %% [markdown]
# #### First, the dataset of all valid Calgary business licenses is uploaded and column titles adjusted.

# %%
YYC_biz_df = pd.read_csv('https://raw.githubusercontent.com/jantyl56A/Coursera_Capstone/master/Calgary_Business_Licenses_Map.csv', sep=',', index_col=None)

#YYC_biz_df.columns

YYC_biz_df.head()
# Out:
#                 TRADENAME              ADDRESS  \
# 0  POLAR WINDOW OF CANADA  #103 3953 112 AV SE
# 1         JARVIS INTERIOR        4615 8A ST NE
# 2     WESTLAND APARTMENTS       4231 BOW TR SW
# 3   RICKY'S ALL DAY GRILL  #1668 1632 14 AV NW
# 4       BLOWERS & GRAFTON         2120 4 ST SW
#
#                                        LICENCETYPES  \
# 0                          RETAIL DEALER - PREMISES
# 1                                        CONTRACTOR
# 2      APARTMENT BUILDING OPERATOR (1 TO 3 STOREYS)
# 3  ALCOHOL BEVERAGE SALES (DRINKING EST/RESTAURANT)
# 4                 FOOD SERVICE - PREMISES (SEATING)
#
#                        COMDISTNM     JOBSTATUSDESC              JOBCREATED  \
# 0        EAST SHEPARD INDUSTRIAL   Pending Renewal  09/30/2013 12:00:00 AM
# 1      GREENVIEW INDUSTRIAL PARK   Pending Renewal  01/24/1995 12:00:00 AM
# 2                    ROSSCARROCK  Renewal Licensed  01/05/1998 12:00:00 AM
# 3  HOUNSFIELD HEIGHTS/BRIAR HILL  Renewal Licensed  09/03/2010 12:00:00 AM
# 4                        MISSION          Licensed  07/10/2020 12:00:00 AM
#
#     longitude   latitude
# 0 -113.980378  50.952254
# 1 -114.042752  51.092998
# 2 -114.148705  51.047190
# 3 -114.099809  51.065921
# 4 -114.071253  51.033575

# %%
YYC_biz_df.columns = ['Tradename', 'Address','License Type','Community','Status','Established', 'Longitude', 'Latitude']
YYC_biz_df.head(20)
# Out:
#                               Tradename                 Address  \
# 0                POLAR WINDOW OF CANADA     #103 3953 112 AV SE
# 1                       JARVIS INTERIOR           4615 8A ST NE
# 2                   WESTLAND APARTMENTS          4231 BOW TR SW
# 3                 RICKY'S ALL DAY GRILL     #1668 1632 14 AV NW
# 4                     BLOWERS & GRAFTON            2120 4 ST SW
# 5                           TIM HORTONS      #500 8338 18 ST SE
# 6                      DISCOVERY POINTE            1121 6 AV SW
# 7                      PROALTA SERVICES       429 MANITOU RD SE
# 8                             MY DONAIR       #25 1200 37 ST SW
# 9                 SPECIAL EVENT RENTALS      #101 2312 52 AV SE
# 10               BASSANO GROWERS (2011)  #118 85 FREEPORT BV NE
# 11                         RALLY POINTE          11511 35 ST SE
# 12             G S L CHEVROLET CADILLAC          1720 BOW TR SW
# 13                         HAIR PASSION        #6 4604 37 ST SW
# 14                         RALLY POINTE          11511 35 ST SE
# 15                     4307 VILLA CR NW        4307 VILLA CR NW
# 16                       MINI FOOD MART    440 ERIN WOODS DR SE
# 17                    INNER BALANCE SPA       #101 424 10 ST NW
# 18  CENTRE FOR WHOLENESS AND WELL-BEING         #3 2312 4 ST SW
# 19                           SPIRITLEAF        #10 217 19 ST NW
#
#                                         License Type  \
# 0                           RETAIL DEALER - PREMISES
# 1                                         CONTRACTOR
# 2       APARTMENT BUILDING OPERATOR (1 TO 3 STOREYS)
# 3   ALCOHOL BEVERAGE SALES (DRINKING EST/RESTAURANT)
# 4                  FOOD SERVICE - PREMISES (SEATING)
# 5                           RETAIL DEALER - PREMISES
# 6    APARTMENT BUILDING OPERATOR (4 OR MORE STOREYS)
# 7                                         CONTRACTOR
# 8               FOOD SERVICE - PREMISES (NO SEATING)
# 9                           RETAIL DEALER - PREMISES
# 10                           FOOD SERVICE - PREMISES
# 11               ALCOHOL BEVERAGE SALES (RESTAURANT)
# 12                 FOOD SERVICE - PREMISES (SEATING)
# 13                                  PERSONAL SERVICE
# 14                                  PERSONAL SERVICE
# 15                                     LODGING HOUSE
# 16                          RETAIL DEALER - PREMISES
# 17                       MASSAGE CENTRE (COMMERCIAL)
# 18                       MASSAGE CENTRE (COMMERCIAL)
# 19                          RETAIL DEALER - PREMISES
#
#                         Community            Status             Established  \
# 0         EAST SHEPARD INDUSTRIAL   Pending Renewal  09/30/2013 12:00:00 AM
# 1       GREENVIEW INDUSTRIAL PARK   Pending Renewal  01/24/1995 12:00:00 AM
# 2                     ROSSCARROCK  Renewal Licensed  01/05/1998 12:00:00 AM
# 3   HOUNSFIELD HEIGHTS/BRIAR HILL  Renewal Licensed  09/03/2010 12:00:00 AM
# 4                         MISSION          Licensed  07/10/2020 12:00:00 AM
# 5                       RIVERBEND  Renewal Licensed  09/26/2019 12:00:00 AM
# 6               DOWNTOWN WEST END  Renewal Licensed  02/27/2019 12:00:00 AM
# 7           MANCHESTER INDUSTRIAL   Pending Renewal  10/29/2013 12:00:00 AM
# 8                     ROSSCARROCK  Renewal Licensed  05/23/2008 12:00:00 AM
# 9                     VALLEYFIELD  Renewal Licensed  11/30/2007 12:00:00 AM
# 10                       STONEY 2  Renewal Licensed  02/17/2015 12:00:00 AM
# 11             SHEPARD INDUSTRIAL  Renewal Licensed  01/10/2007 12:00:00 AM
# 12                        SUNALTA  Renewal Licensed  10/07/1994 12:00:00 AM
# 13                   RUTLAND PARK  Renewal Licensed  09/20/1999 12:00:00 AM
# 14             SHEPARD INDUSTRIAL  Renewal Licensed  01/10/2007 12:00:00 AM
# 15                        VARSITY   Pending Renewal  03/23/2018 12:00:00 AM
# 16                     ERIN WOODS   Pending Renewal  04/25/2013 12:00:00 AM
# 17                      SUNNYSIDE   Pending Renewal  10/01/2003 12:00:00 AM
# 18                        MISSION  Renewal Licensed  09/27/2019 12:00:00 AM
# 19                 WEST HILLHURST   Pending Renewal  08/29/2019 12:00:00 AM
#
#      Longitude   Latitude
# 0  -113.980378  50.952254
# 1  -114.042752  51.092998
# 2  -114.148705  51.047190
# 3  -114.099809  51.065921
# 4  -114.071253  51.033575
# 5  -114.015104  50.977481
# 6  -114.087478  51.047883
# 7  -114.054048  51.010203
# 8  -114.140366  51.041643
# 9  -114.006146  51.007415
# 10 -114.010603  51.149767
# 11 -113.985855  50.947604
# 12 -114.101279  51.046323
# 13 -114.140375  51.014194
# 14 -113.985855  50.947604
# 15 -114.142093  51.090487
# 16 -113.959688  51.023957
# 17 -114.085614  51.056519
# 18 -114.071137  51.031747
# 19 -114.105774  51.054110

# %%
#How many business entities there are in individual communities.
YYC_biz_df['Community'].value_counts()
# Out:
# BELTLINE                         1578
# DOWNTOWN COMMERCIAL CORE         1452
# MANCHESTER INDUSTRIAL            1273
# FOOTHILLS                        1130
# EAST SHEPARD INDUSTRIAL           767
#                                  ...
# CORNERSTONE                         1
# TWINHILLS                           1
# MEDICINE HILL                       1
# MAYFAIR                             1
# RESIDUAL WARD 2 - SUB AREA 2C       1
# Name: Community, Length: 258, dtype: int64

# %%
#How many business entities there are in Calgary.
YYC_biz_df['License Type'].value_counts()
YYC_biz_df
# Out:
#                         Tradename                   Address  \
# 0          POLAR WINDOW OF CANADA       #103 3953 112 AV SE
# 1                 JARVIS INTERIOR             4615 8A ST NE
# 2             WESTLAND APARTMENTS            4231 BOW TR SW
# 3           RICKY'S ALL DAY GRILL       #1668 1632 14 AV NW
# 4               BLOWERS & GRAFTON              2120 4 ST SW
# ...                           ...                       ...
# 32190     HELLO GORGEOUS SKIN LAB          #2 2507 14 ST SW
# 32191  SMARTECH COMPUTERS & PHOTO  #4101 230 EVERSYDE BV SW
# 32192    ANGLES HAIR & AESTHETICS         #13 1200 37 ST SW
# 32193                       STEEL         #30 3260 46 AV SE
# 32194                   BUNDESCAR       #2113 4905 30 ST SE
#
#                                            License Type  \
# 0                              RETAIL DEALER - PREMISES
# 1                                            CONTRACTOR
# 2          APARTMENT BUILDING OPERATOR (1 TO 3 STOREYS)
# 3      ALCOHOL BEVERAGE SALES (DRINKING EST/RESTAURANT)
# 4                     FOOD SERVICE - PREMISES (SEATING)
# ...                                                 ...
# 32190                                  PERSONAL SERVICE
# 32191                                      PHOTOGRAPHER
# 32192                                  PERSONAL SERVICE
# 32193                                      MANUFACTURER
# 32194              MOTOR VEHICLE REPAIR AND SERVICE (1)
#
#                            Community            Status  \
# 0            EAST SHEPARD INDUSTRIAL   Pending Renewal
# 1          GREENVIEW INDUSTRIAL PARK   Pending Renewal
# 2                        ROSSCARROCK  Renewal Licensed
# 3      HOUNSFIELD HEIGHTS/BRIAR HILL  Renewal Licensed
# 4                            MISSION          Licensed
# ...                              ...               ...
# 32190                       BANKVIEW  Renewal Licensed
# 32191                      EVERGREEN  Renewal Licensed
# 32192                    ROSSCARROCK  Renewal Licensed
# 32193                GOLDEN TRIANGLE          Licensed
# 32194                GOLDEN TRIANGLE  Renewal Licensed
#
#                   Established   Longitude   Latitude
# 0      09/30/2013 12:00:00 AM -113.980378  50.952254
# 1      01/24/1995 12:00:00 AM -114.042752  51.092998
# 2      01/05/1998 12:00:00 AM -114.148705  51.047190
# 3      09/03/2010 12:00:00 AM -114.099809  51.065921
# 4      07/10/2020 12:00:00 AM -114.071253  51.033575
# ...                       ...         ...        ...
# 32190  05/07/2015 12:00:00 AM -114.095188  51.031900
# 32191  06/17/2016 12:00:00 AM -114.110080  50.908448
# 32192  12/12/2007 12:00:00 AM -114.139741  51.042287
# 32193  04/22/2020 12:00:00 AM -113.987542  51.012677
# 32194  05/01/2016 12:00:00 AM -113.989366  51.010458
#
# [32195 rows x 8 columns]

# %% [markdown]
# #### Liquor stores, restaurants, bars and pubs in Calgary

# %%
#First, how many liquor store licenses there are in Calgary.
YYC_liq_df1=YYC_biz_df.loc[YYC_biz_df['License Type']=='LIQUOR STORE']
YYC_liq_df1
# Out:
#                                     Tradename                       Address  \
# 31                        ZYN THE WINE MARKET            #100 1543 17 AV SE
# 40                               CELLAR (THE)              #100 137 8 AV SW
# 65     SOBEYS SPIRITS WINE COLD BEER CRANSTON      #4010 356 CRANSTON RD SE
# 188                     SOMERSET LIQUOR STORE        16329 SOMERCREST ST SW
# 212                       BSW LIQUOR AVIATION       #134 425 AVIATION RD NE
# ...                                       ...                           ...
# 31914                      CANADIAN LIQUOR #3              #9 1603 62 AV SE
# 31918  ACE LIQUOR DISCOUNTER AT COUNTRY HILLS  #303 500 COUNTRY HILLS BV NE
# 32030                             LIQUOR BANK            #101 3509 17 AV SE
# 32060                        A-Z LIQUOR STORE                11257 30 ST SW
# 32100                   ASPEN WINE & SPIRIT'S     #130 366 ASPEN GLEN LD SW
#
#        License Type                      Community            Status  \
# 31     LIQUOR STORE               ALYTH/BONNYBROOK   Pending Renewal
# 40     LIQUOR STORE       DOWNTOWN COMMERCIAL CORE   Pending Renewal
# 65     LIQUOR STORE                       CRANSTON  Renewal Licensed
# 188    LIQUOR STORE                       SOMERSET  Renewal Licensed
# 212    LIQUOR STORE  CALGARY INTERNATIONAL AIRPORT   Pending Renewal
# ...             ...                            ...               ...
# 31914  LIQUOR STORE                          OGDEN  Renewal Licensed
# 31918  LIQUOR STORE          COUNTRY HILLS VILLAGE  Renewal Licensed
# 32030  LIQUOR STORE                      SOUTHVIEW  Renewal Licensed
# 32060  LIQUOR STORE                      CEDARBRAE  Renewal Licensed
# 32100  LIQUOR STORE                    ASPEN WOODS  Renewal Licensed
#
#                   Established   Longitude   Latitude
# 31     11/03/2008 12:00:00 AM -114.027838  51.036524
# 40     11/14/2001 12:00:00 AM -114.065148  51.045335
# 65     06/19/2009 12:00:00 AM -113.976173  50.880257
# 188    07/09/2004 12:00:00 AM -114.090439  50.903410
# 212    10/15/2019 12:00:00 AM -114.030416  51.096781
# ...                       ...         ...        ...
# 31914  09/09/2016 12:00:00 AM -114.020153  50.997441
# 31918  01/10/2019 12:00:00 AM -114.057230  51.155421
# 32030  12/01/2008 12:00:00 AM -113.983785  51.037386
# 32060  05/04/2012 12:00:00 AM -114.129842  50.953105
# 32100  12/14/2009 12:00:00 AM -114.209407  51.039981
#
# [374 rows x 8 columns]

# %%
#Second, how many restaurants, bars and pubs licenses there are in Calgary.
YYC_liq_df2=YYC_biz_df.loc[YYC_biz_df['License Type']=='ALCOHOL BEVERAGE SALES (RESTAURANT)']
YYC_liq_df2
# Out:
#                                                Tradename              Address  \
# 11                                          RALLY POINTE       11511 35 ST SE
# 45     NATIONAL FINE FOOD, BEER & SPIRITS (NATIONAL 1...         341 10 AV SW
# 130                        GRAVITY ESPRESSO AND WINE BAR         908 13 AV SW
# 141                                     LEOPOLD'S TAVERN   6512 BOWNESS RD NW
# 185                       STANLEY PARK LAWN BOWLING CLUB         350 42 AV SW
# ...                                                  ...                  ...
# 32120                                     DEVILLE COFFEE          807 1 ST SW
# 32143           GOOD EARTH COFFEE HOUSE CENTENNIAL PLACE     #110 520 3 AV SW
# 32145                                SS106 APERITIVO BAR  824D EDMONTON TR NE
# 32179                       FRANK SISSON'S SILVER DOLLAR         4303 9 ST SE
# 32186                               FANCY TASTE OF CHINA       1160 137 AV SE
#
#                               License Type                 Community  \
# 11     ALCOHOL BEVERAGE SALES (RESTAURANT)        SHEPARD INDUSTRIAL
# 45     ALCOHOL BEVERAGE SALES (RESTAURANT)                  BELTLINE
# 130    ALCOHOL BEVERAGE SALES (RESTAURANT)                  BELTLINE
# 141    ALCOHOL BEVERAGE SALES (RESTAURANT)                   BOWNESS
# 185    ALCOHOL BEVERAGE SALES (RESTAURANT)                  PARKHILL
# ...                                    ...                       ...
# 32120  ALCOHOL BEVERAGE SALES (RESTAURANT)  DOWNTOWN COMMERCIAL CORE
# 32143  ALCOHOL BEVERAGE SALES (RESTAURANT)                EAU CLAIRE
# 32145  ALCOHOL BEVERAGE SALES (RESTAURANT)                   RENFREW
# 32179  ALCOHOL BEVERAGE SALES (RESTAURANT)                 HIGHFIELD
# 32186  ALCOHOL BEVERAGE SALES (RESTAURANT)                DEER RIDGE
#
#                  Status             Established   Longitude   Latitude
# 11     Renewal Licensed  01/10/2007 12:00:00 AM -113.985855  50.947604
# 45     Renewal Licensed  08/21/2012 12:00:00 AM -114.070289  51.043270
# 130     Pending Renewal  09/30/2019 12:00:00 AM -114.082066  51.041590
# 141    Renewal Licensed  05/09/2018 12:00:00 AM -114.182186  51.086814
# 185     Pending Renewal  08/18/2008 12:00:00 AM -114.069523  51.015875
# ...                 ...                     ...         ...        ...
# 32120  Renewal Licensed  10/08/2018 12:00:00 AM -114.065818  51.045355
# 32143  Renewal Licensed  05/22/2018 12:00:00 AM -114.072113  51.050860
# 32145  Renewal Licensed  02/08/2016 12:00:00 AM -114.053894  51.059225
# 32179  Renewal Licensed  03/13/2008 12:00:00 AM -114.040824  51.014929
# 32186   Pending Renewal  03/31/2016 12:00:00 AM -114.027857  50.928348
#
# [1278 rows x 8 columns]

# %%
#Let's merge the liquor stores and restaurants, pubs and bars dataframes.
frames = (YYC_liq_df1,YYC_liq_df2)
YYC_liq_df = pd.concat(frames)
YYC_liq_df
# Out:
#                                       Tradename                   Address  \
# 31                          ZYN THE WINE MARKET        #100 1543 17 AV SE
# 40                                 CELLAR (THE)          #100 137 8 AV SW
# 65       SOBEYS SPIRITS WINE COLD BEER CRANSTON  #4010 356 CRANSTON RD SE
# 188                       SOMERSET LIQUOR STORE    16329 SOMERCREST ST SW
# 212                         BSW LIQUOR AVIATION   #134 425 AVIATION RD NE
# ...                                         ...                       ...
# 32120                            DEVILLE COFFEE               807 1 ST SW
# 32143  GOOD EARTH COFFEE HOUSE CENTENNIAL PLACE          #110 520 3 AV SW
# 32145                       SS106 APERITIVO BAR       824D EDMONTON TR NE
# 32179              FRANK SISSON'S SILVER DOLLAR              4303 9 ST SE
# 32186                      FANCY TASTE OF CHINA            1160 137 AV SE
#
#                               License Type                      Community  \
# 31                            LIQUOR STORE               ALYTH/BONNYBROOK
# 40                            LIQUOR STORE       DOWNTOWN COMMERCIAL CORE
# 65                            LIQUOR STORE                       CRANSTON
# 188                           LIQUOR STORE                       SOMERSET
# 212                           LIQUOR STORE  CALGARY INTERNATIONAL AIRPORT
# ...                                    ...                            ...
# 32120  ALCOHOL BEVERAGE SALES (RESTAURANT)       DOWNTOWN COMMERCIAL CORE
# 32143  ALCOHOL BEVERAGE SALES (RESTAURANT)                     EAU CLAIRE
# 32145  ALCOHOL BEVERAGE SALES (RESTAURANT)                        RENFREW
# 32179  ALCOHOL BEVERAGE SALES (RESTAURANT)                      HIGHFIELD
# 32186  ALCOHOL BEVERAGE SALES (RESTAURANT)                     DEER RIDGE
#
#                  Status             Established   Longitude   Latitude
# 31      Pending Renewal  11/03/2008 12:00:00 AM -114.027838  51.036524
# 40      Pending Renewal  11/14/2001 12:00:00 AM -114.065148  51.045335
# 65     Renewal Licensed  06/19/2009 12:00:00 AM -113.976173  50.880257
# 188    Renewal Licensed  07/09/2004 12:00:00 AM -114.090439  50.903410
# 212     Pending Renewal  10/15/2019 12:00:00 AM -114.030416  51.096781
# ...                 ...                     ...         ...        ...
# 32120  Renewal Licensed  10/08/2018 12:00:00 AM -114.065818  51.045355
# 32143  Renewal Licensed  05/22/2018 12:00:00 AM -114.072113  51.050860
# 32145  Renewal Licensed  02/08/2016 12:00:00 AM -114.053894  51.059225
# 32179  Renewal Licensed  03/13/2008 12:00:00 AM -114.040824  51.014929
# 32186   Pending Renewal  03/31/2016 12:00:00 AM -114.027857  50.928348
#
# [1652 rows x 8 columns]

# %% [markdown]
# ## Sorting the establishments by Community

# %%
YYC_liq_df_sorted = YYC_liq_df.sort_values(by=['Community',], inplace=False, ascending=True)
YYC_liq_df_sorted
# Out:
#                                   Tradename                    Address  \
# 12230                      ABLO (ABBEYDALE)               822 68 ST NE
# 17038                   ABBEYDALE COMMUNITY        821 ABBEYDALE DR NE
# 20453     CHINE LEGENDARY HOT POT & NOODLES     8971 BONAVENTURE DR SE
# 13130         MUCHO BURRITO FAIRMOUNT DRIVE  #130 9825 FAIRMOUNT DR SE
# 14559                GOLDEN GATE RESTAURANT       #14 430 ACADIA DR SE
# ...                                     ...                        ...
# 8256                   PATISSERIE DU SOLIEL   #309 2525 WOODVIEW DR SW
# 30991             WOODBINE B K LIQUOR STORE      #C 464 WOODBINE BV SW
# 15036     ACE LIQUOR DISCOUNTER AT WOODBINE   #204 2525 WOODVIEW DR SW
# 28966                 WOODPARK LIQUOR STORE     #14 523 WOODPARK BV SW
# 18904  CANYON MEADOWS GOLF AND COUNTRY CLUB          #A 12501 14 ST SW
#
#                               License Type  Community            Status  \
# 12230                         LIQUOR STORE  ABBEYDALE   Pending Renewal
# 17038  ALCOHOL BEVERAGE SALES (RESTAURANT)  ABBEYDALE  Renewal Licensed
# 20453  ALCOHOL BEVERAGE SALES (RESTAURANT)     ACADIA  Renewal Licensed
# 13130  ALCOHOL BEVERAGE SALES (RESTAURANT)     ACADIA  Renewal Licensed
# 14559  ALCOHOL BEVERAGE SALES (RESTAURANT)     ACADIA  Renewal Licensed
# ...                                    ...        ...               ...
# 8256   ALCOHOL BEVERAGE SALES (RESTAURANT)   WOODBINE  Renewal Licensed
# 30991                         LIQUOR STORE   WOODBINE  Renewal Licensed
# 15036                         LIQUOR STORE   WOODBINE   Pending Renewal
# 28966                         LIQUOR STORE  WOODLANDS  Renewal Licensed
# 18904  ALCOHOL BEVERAGE SALES (RESTAURANT)  WOODLANDS  Renewal Licensed
#
#                   Established   Longitude   Latitude
# 12230  08/21/2017 12:00:00 AM -113.934380  51.059158
# 17038  02/05/1999 12:00:00 AM -113.932329  51.059753
# 20453  09/13/2017 12:00:00 AM -114.069514  50.973351
# 13130  04/03/2019 12:00:00 AM -114.059242  50.964289
# 14559  07/15/2013 12:00:00 AM -114.047913  50.969766
# ...                       ...         ...        ...
# 8256   06/03/2010 12:00:00 AM -114.121133  50.940540
# 30991  03/30/2005 12:00:00 AM -114.133474  50.946462
# 15036  09/21/2004 12:00:00 AM -114.120083  50.940327
# 28966  06/04/2007 12:00:00 AM -114.109716  50.940752
# 18904  10/07/1994 12:00:00 AM -114.095957  50.941746
#
# [1652 rows x 8 columns]

# %%
YYC_liq_df_sorted.shape
# Out:
# (1652, 8)

# %%
print("Dimension of dataset: YYC_liq_df_sorted.shape")
YYC_liq_df_sorted.dtypes
# Out:
# Dimension of dataset: YYC_liq_df_sorted.shape
# Tradename        object
# Address          object
# License Type     object
# Community        object
# Status           object
# Established      object
# Longitude       float64
# Latitude        float64
# dtype: object

# %%
# How many ALCOHOL BEVERAGE SALES spots, i.e. liquor stores, restaurants, bars and pubs there are in each Community.
YYC_liq_count=YYC_liq_df_sorted.groupby('Community').count()
YYC_liq_count
# Out:
#                               Tradename  Address  License Type  Status  \
# Community
# ABBEYDALE                             2        2             2       2
# ACADIA                               23       23            23      23
# ALBERT PARK/RADISSON HEIGHTS          8        8             8       8
# ALTADORE                              7        7             7       7
# ALYTH/BONNYBROOK                      6        6             6       6
# ...                                 ...      ...           ...     ...
# WILLOW PARK                          15       15            15      15
# WINDSOR PARK                          6        6             6       6
# WINSTON HEIGHTS/MOUNTVIEW             8        8             8       8
# WOODBINE                              4        4             4       4
# WOODLANDS                             2        2             2       2
#
#                               Established  Longitude  Latitude
# Community
# ABBEYDALE                               2          2         2
# ACADIA                                 23         23        23
# ALBERT PARK/RADISSON HEIGHTS            8          8         8
# ALTADORE                                7          7         7
# ALYTH/BONNYBROOK                        6          6         6
# ...                                   ...        ...       ...
# WILLOW PARK                            15         15        15
# WINDSOR PARK                            6          6         6
# WINSTON HEIGHTS/MOUNTVIEW               8          8         8
# WOODBINE                                4          4         4
# WOODLANDS                               2          2         2
#
# [212 rows x 7 columns]

# %% [markdown]
# ## Cleaning the dataframe

# %%
import numpy as np
YYC_liq_red = YYC_liq_count.drop(YYC_liq_count.columns[np.r_[:2, 3,4,5,6]], axis=1)
YYC_liq_red1=YYC_liq_red.rename(columns={'License Type':'Number of Licenses'})
YYC_liq_red1
# Out:
#                               Number of Licenses
# Community
# ABBEYDALE                                      2
# ACADIA                                        23
# ALBERT PARK/RADISSON HEIGHTS                   8
# ALTADORE                                       7
# ALYTH/BONNYBROOK                               6
# ...                                          ...
# WILLOW PARK                                   15
# WINDSOR PARK                                   6
# WINSTON HEIGHTS/MOUNTVIEW                      8
# WOODBINE                                       4
# WOODLANDS                                      2
#
# [212 rows x 1 columns]

# %% [markdown]
# ## Top 20 Communities by number of Alcohol Beverage Sales spots

# %%
YYC_liq_ordered = YYC_liq_red1.sort_values(by=['Number of Licenses'], ascending = False, axis = 0, inplace = False)
YYC_liq_ordered.head(20)
# Out:
#                                Number of Licenses
# Community
# BELTLINE                                      129
# DOWNTOWN COMMERCIAL CORE                       92
# HILLHURST                                      32
# CALGARY INTERNATIONAL AIRPORT                  27
# SUNRIDGE                                       27
# INGLEWOOD                                      27
# CHINATOWN                                      25
# BRIDGELAND/RIVERSIDE                           25
# MANCHESTER INDUSTRIAL                          24
# ACADIA                                         23
# CRESCENT HEIGHTS                               22
# ARBOUR LAKE                                    22
# FAIRVIEW INDUSTRIAL                            22
# TUXEDO PARK                                    20
# HAYSBORO                                       20
# SOUTH AIRWAYS                                  19
# FOREST LAWN                                    18
# MISSION                                        18
# SIGNAL HILL                                    18
# ROYAL VISTA                                    18

# %%
# convert column "Number of Licenses" of a DataFrame
YYC_liq_ordered["Number of Licenses"] = pd.to_numeric(YYC_liq_ordered["Number of Licenses"])
dtype: int

# %%
YYC_liq_top10 = YYC_liq_ordered.iloc[0:10]
YYC_liq_top10
# Out:
#                                Number of Licenses
# Community
# BELTLINE                                      129
# DOWNTOWN COMMERCIAL CORE                       92
# HILLHURST                                      32
# CALGARY INTERNATIONAL AIRPORT                  27
# SUNRIDGE                                       27
# INGLEWOOD                                      27
# CHINATOWN                                      25
# BRIDGELAND/RIVERSIDE                           25
# MANCHESTER INDUSTRIAL                          24
# ACADIA                                         23

# %%
YYC_liq_top10.index_col='1'
YYC_liq_top10.shape
# Out:
# (10, 1)

# %%
YYC_liq = YYC_liq_top10[['Number of Licenses']]

YYC_liq.set_index('Number of Licenses',inplace = True)

ax = YYC_liq_top10.plot(kind='barh', figsize=(10, 6), rot=0)

ax.set_ylabel('Community')
ax.set_xlabel('Number of Licenses')
ax.set_title('Communities in Calgary with the Highest Number of Alcohol Licenses')

for p in ax.patches:
    ax.annotate(np.round(p.get_height(),decimals=2), 
                (p.get_x()+p.get_width()/2., p.get_height()), 
                ha='center', 
                va='center', 
                xytext=(0, 10), 
                textcoords='offset points',
                fontsize = 14,
               )

plt.show()

# %%
YYC_liq_low10 = YYC_liq_ordered.iloc[179:189]
YYC_liq_low10
# Out:
#                  Number of Licenses
# Community
# COLLINGWOOD                       1
# BAYVIEW                           1
# CORNERSTONE                       1
# CHRISTIE PARK                     1
# COUGAR RIDGE                      1
# DEER RUN                          1
# BONAVISTA DOWNS                   1
# ELBOW PARK                        1
# ERLTON                            1
# CEDARBRAE                         1

# %%
YYC_liq1 = YYC_liq_low10[['Number of Licenses']]

YYC_liq1.set_index('Number of Licenses',inplace = True)

ax = YYC_liq_low10.plot(kind='barh', figsize=(10, 6), rot=0)

ax.set_ylabel('Community')
ax.set_xlabel('Number of Licenses')
ax.set_title('Communities in Calgary with the Lowest Number of Alcohol Licenses')

for p in ax.patches:
    ax.annotate(np.round(p.get_height(),decimals=2), 
                (p.get_x()+p.get_width()/2., p.get_height()), 
                ha='center', 
                va='center', 
                xytext=(0, 10), 
                textcoords='offset points',
                fontsize = 14,
               )

plt.show()

# %%
YYC_liq_df_sorted=YYC_liq_df_sorted.dropna(subset=['Longitude'])

YYC_liq_df_sorted=YYC_liq_df_sorted.dropna(subset=['Latitude'])

# %%
# Calgary latitude and longitude values
latitude = 51.04
longitude = -114.07

# define Calgary map 
Calgary_map = folium.Map(location=[latitude, longitude], zoom_start=12)

# add markers to map
for lat, lng, label in zip(YYC_liq_df_sorted['Latitude'], YYC_liq_df_sorted['Longitude'], YYC_liq_df_sorted['Community']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(Calgary_map)  
    
Calgary_map
# display Calgary map
Calgary_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
YYC_liq_df1=YYC_liq_df.drop(YYC_liq_df.columns[np.r_[1,2,3,4,5]], axis=1)
YYC_liq_df1.head()
# Out:
#                                   Tradename   Longitude   Latitude
# 31                      ZYN THE WINE MARKET -114.027838  51.036524
# 40                             CELLAR (THE) -114.065148  51.045335
# 65   SOBEYS SPIRITS WINE COLD BEER CRANSTON -113.976173  50.880257
# 188                   SOMERSET LIQUOR STORE -114.090439  50.903410
# 212                     BSW LIQUOR AVIATION -114.030416  51.096781

# %% [markdown]
# ## Clustering Calgary Communities on the basis of Alcohol Beverage Licenses

# %%
YYC_liq_df1=YYC_liq_df1.dropna(subset=['Longitude'])

YYC_liq_df1=YYC_liq_df1.dropna(subset=['Latitude'])

# %%
K_clusters = range(1,10)
kmeans = [KMeans(n_clusters=i) for i in K_clusters]
Y_axis = YYC_liq_df1[['Latitude']]
X_axis = YYC_liq_df1[['Longitude']]
score = [kmeans[i].fit(Y_axis).score(Y_axis) for i in range(len(kmeans))]
# Visualize
plt.plot(K_clusters, score)
plt.xlabel('Number of Clusters')
plt.ylabel('Score')
plt.title('Elbow Curve')
plt.show()

# %% [markdown]
# #### K-means clustering

# %%
calgary_grouped_clustering = YYC_liq_df1.drop('Tradename', 1)
calgary_grouped_clustering=calgary_grouped_clustering.dropna(subset=['Longitude'])
calgary_grouped_clustering=calgary_grouped_clustering.dropna(subset=['Latitude'])

#K means Clustering 
def doKmeans(X, nclust=8):
    model = KMeans(nclust)
    model.fit(X)
    clust_labels = model.predict(X)
    cent = model.cluster_centers_
    return (clust_labels, cent)

clust_labels, cent = doKmeans(calgary_grouped_clustering, 8)
kmeans = pd.DataFrame(clust_labels)
calgary_grouped_clustering.insert((calgary_grouped_clustering.shape[1]),'kmeans',kmeans)

# %%
#Plot the clusters obtained using k means
fig = plt.figure()
ax = fig.add_subplot(111)
scatter = ax.scatter(calgary_grouped_clustering['Latitude'], calgary_grouped_clustering['Longitude'],
                     c=kmeans[0],s=50)
ax.set_title('K-Means Clustering')
ax.set_xlabel('Latitude')
ax.set_ylabel('Longitude')
plt.colorbar(scatter)

# %%
calgary_grouped_clustering.loc[calgary_grouped_clustering['kmeans'] == 0, calgary_grouped_clustering.columns[[0] + list(range(1, calgary_grouped_clustering.shape[1]))]]
calgary_grouped_clustering["Cluster Labels"] = clust_labels
calgary_grouped_clustering.head(10)
# Out:
#       Longitude   Latitude  kmeans  Cluster Labels
# 31  -114.027838  51.036524     7.0               5
# 40  -114.065148  51.045335     4.0               5
# 65  -113.976173  50.880257     0.0               6
# 188 -114.090439  50.903410     5.0               3
# 212 -114.030416  51.096781     1.0               1
# 260 -114.211493  51.041271     3.0               7
# 266 -114.146726  51.101784     4.0               0
# 271 -114.145965  51.077951     5.0               7
# 272 -113.963079  50.930416     4.0               6
# 306 -113.955757  51.098806     5.0               4

# %% [markdown]
# #### Merging the clustered data and initial dataframe

# %%
calgary_merged = pd.merge(YYC_liq_df_sorted,calgary_grouped_clustering).drop('kmeans', 1)
calgary_merged
# Out:
#                                  Tradename                    Address  \
# 0                         ABLO (ABBEYDALE)               822 68 ST NE
# 1                      ABBEYDALE COMMUNITY        821 ABBEYDALE DR NE
# 2        CHINE LEGENDARY HOT POT & NOODLES     8971 BONAVENTURE DR SE
# 3            MUCHO BURRITO FAIRMOUNT DRIVE  #130 9825 FAIRMOUNT DR SE
# 4                   GOLDEN GATE RESTAURANT       #14 430 ACADIA DR SE
# ...                                    ...                        ...
# 1996                  PATISSERIE DU SOLIEL   #309 2525 WOODVIEW DR SW
# 1997             WOODBINE B K LIQUOR STORE      #C 464 WOODBINE BV SW
# 1998     ACE LIQUOR DISCOUNTER AT WOODBINE   #204 2525 WOODVIEW DR SW
# 1999                 WOODPARK LIQUOR STORE     #14 523 WOODPARK BV SW
# 2000  CANYON MEADOWS GOLF AND COUNTRY CLUB          #A 12501 14 ST SW
#
#                              License Type  Community            Status  \
# 0                            LIQUOR STORE  ABBEYDALE   Pending Renewal
# 1     ALCOHOL BEVERAGE SALES (RESTAURANT)  ABBEYDALE  Renewal Licensed
# 2     ALCOHOL BEVERAGE SALES (RESTAURANT)     ACADIA  Renewal Licensed
# 3     ALCOHOL BEVERAGE SALES (RESTAURANT)     ACADIA  Renewal Licensed
# 4     ALCOHOL BEVERAGE SALES (RESTAURANT)     ACADIA  Renewal Licensed
# ...                                   ...        ...               ...
# 1996  ALCOHOL BEVERAGE SALES (RESTAURANT)   WOODBINE  Renewal Licensed
# 1997                         LIQUOR STORE   WOODBINE  Renewal Licensed
# 1998                         LIQUOR STORE   WOODBINE   Pending Renewal
# 1999                         LIQUOR STORE  WOODLANDS  Renewal Licensed
# 2000  ALCOHOL BEVERAGE SALES (RESTAURANT)  WOODLANDS  Renewal Licensed
#
#                  Established   Longitude   Latitude  Cluster Labels
# 0     08/21/2017 12:00:00 AM -113.934380  51.059158               4
# 1     02/05/1999 12:00:00 AM -113.932329  51.059753               4
# 2     09/13/2017 12:00:00 AM -114.069514  50.973351               2
# 3     04/03/2019 12:00:00 AM -114.059242  50.964289               2
# 4     07/15/2013 12:00:00 AM -114.047913  50.969766               2
# ...                      ...         ...        ...             ...
# 1996  06/03/2010 12:00:00 AM -114.121133  50.940540               3
# 1997  03/30/2005 12:00:00 AM -114.133474  50.946462               3
# 1998  09/21/2004 12:00:00 AM -114.120083  50.940327               3
# 1999  06/04/2007 12:00:00 AM -114.109716  50.940752               3
# 2000  10/07/1994 12:00:00 AM -114.095957  50.941746               3
#
# [2001 rows x 9 columns]

# %% [markdown]
# #### Venues included in individual clusters

# %%
calgary_merged.loc[calgary_merged['Cluster Labels'] == 0, calgary_merged.columns[[0] + list(range(1, calgary_merged.shape[1]))]]
# Out:
#                                Tradename                     Address  \
# 52                       CALIFORNIA THAI      #410 20 CROWFOOT CR NW
# 53                           LIQUOR TOWN           37 CROWFOOT RI NW
# 54       CROWFOOT SAFEWAY WINE & SPIRITS           65 CROWFOOT CR NW
# 55         CALGARY CO-OP WINES & SPIRITS           39 CROWFOOT WY NW
# 56        NEW DYNASTY SEAFOOD RESTAURANT     #201 150 CROWFOOT CR NW
# ...                                  ...                         ...
# 1893  SILVER SPRINGS GOLF & COUNTRY CLUB  1600 VARSITY ESTATES DR NW
# 1895   GARDEN CAFE & THE FIRESIDE LOUNGE    40 VARSITY ESTATES CI NW
# 1896                         SNOW PALACE    #1B 5403 CROWCHILD TR NW
# 1899                     1977730 ALBERTA   #210 5403 CROWCHILD TR NW
# 1902                  BIG COUNTRY LIQUOR   #122 5403 CROWCHILD TR NW
#
#                              License Type    Community            Status  \
# 52    ALCOHOL BEVERAGE SALES (RESTAURANT)  ARBOUR LAKE  Renewal Licensed
# 53                           LIQUOR STORE  ARBOUR LAKE  Renewal Licensed
# 54                           LIQUOR STORE  ARBOUR LAKE   Pending Renewal
# 55                           LIQUOR STORE  ARBOUR LAKE   Pending Renewal
# 56    ALCOHOL BEVERAGE SALES (RESTAURANT)  ARBOUR LAKE  Renewal Licensed
# ...                                   ...          ...               ...
# 1893  ALCOHOL BEVERAGE SALES (RESTAURANT)      VARSITY  Renewal Licensed
# 1895  ALCOHOL BEVERAGE SALES (RESTAURANT)      VARSITY  Renewal Licensed
# 1896  ALCOHOL BEVERAGE SALES (RESTAURANT)      VARSITY   Pending Renewal
# 1899  ALCOHOL BEVERAGE SALES (RESTAURANT)      VARSITY  Renewal Licensed
# 1902                         LIQUOR STORE      VARSITY  Renewal Licensed
#
#                  Established   Longitude   Latitude  Cluster Labels
# 52    07/07/2014 12:00:00 AM -114.198607  51.125666               0
# 53    07/12/2018 12:00:00 AM -114.210920  51.126039               0
# 54    09/20/2013 12:00:00 AM -114.200647  51.125260               0
# 55    10/26/2010 12:00:00 AM -114.200590  51.124539               0
# 56    10/07/1994 12:00:00 AM -114.196097  51.128023               0
# ...                      ...         ...        ...             ...
# 1893  10/07/1994 12:00:00 AM -114.168365  51.097192               0
# 1895  12/13/2017 12:00:00 AM -114.163027  51.103075               0
# 1896  08/27/2014 12:00:00 AM -114.165327  51.103909               0
# 1899  06/24/2016 12:00:00 AM -114.165390  51.103861               0
# 1902  01/22/2019 12:00:00 AM -114.164990  51.103870               0
#
# [120 rows x 9 columns]

# %%
cluster_1=calgary_merged.loc[calgary_merged['Cluster Labels'] == 1, calgary_merged.columns[[0] + list(range(1, calgary_merged.shape[1]))]]
cluster_1
# Out:
#                                 Tradename                         Address  \
# 85                       BOWLS KOREAN BBQ  #1301 9650 HARVEST HILLS BV NE
# 86                                 SHIKHA          9665 AURORA PARK LI NE
# 87                                 SHIKHA          9665 AURORA PARK LI NE
# 88    EXECUTIVE RESIDENCY BY BEST WESTERN          9665 AURORA PARK LI NE
# 89    EXECUTIVE RESIDENCY BY BEST WESTERN          9665 AURORA PARK LI NE
# ...                                   ...                             ...
# 1844      THORNCLIFFE GREENVIEW COMMUNITY               5600 CENTRE ST NE
# 1845           SAFEWAY LIQUOR THORNCLIFFE                    5611 4 ST NW
# 1846                  B K LIQUOR STORE #3                    5608 4 ST NW
# 1847                           TOPS PIZZA                 #7 5602 4 ST NW
# 1848                  VIETWEST RESTAURANT                    5616 4 ST NW
#
#                              License Type             Community  \
# 85    ALCOHOL BEVERAGE SALES (RESTAURANT)  AURORA BUSINESS PARK
# 86    ALCOHOL BEVERAGE SALES (RESTAURANT)  AURORA BUSINESS PARK
# 87    ALCOHOL BEVERAGE SALES (RESTAURANT)  AURORA BUSINESS PARK
# 88    ALCOHOL BEVERAGE SALES (RESTAURANT)  AURORA BUSINESS PARK
# 89    ALCOHOL BEVERAGE SALES (RESTAURANT)  AURORA BUSINESS PARK
# ...                                   ...                   ...
# 1844  ALCOHOL BEVERAGE SALES (RESTAURANT)           THORNCLIFFE
# 1845                         LIQUOR STORE           THORNCLIFFE
# 1846                         LIQUOR STORE           THORNCLIFFE
# 1847  ALCOHOL BEVERAGE SALES (RESTAURANT)           THORNCLIFFE
# 1848  ALCOHOL BEVERAGE SALES (RESTAURANT)           THORNCLIFFE
#
#                 Status             Established   Longitude   Latitude  \
# 85    Renewal Licensed  12/05/2016 12:00:00 AM -114.070102  51.141029
# 86    Renewal Licensed  07/08/2019 12:00:00 AM -114.060440  51.140181
# 87    Renewal Licensed  07/08/2019 12:00:00 AM -114.060440  51.140181
# 88     Pending Renewal  09/16/2019 12:00:00 AM -114.060440  51.140181
# 89     Pending Renewal  09/16/2019 12:00:00 AM -114.060440  51.140181
# ...                ...                     ...         ...        ...
# 1844  Renewal Licensed  11/03/1999 12:00:00 AM -114.061685  51.101493
# 1845   Pending Renewal  09/20/2013 12:00:00 AM -114.072682  51.101941
# 1846  Renewal Licensed  01/04/2006 12:00:00 AM -114.071216  51.101585
# 1847  Renewal Licensed  12/11/1997 12:00:00 AM -114.070688  51.101338
# 1848  Renewal Licensed  03/11/2009 12:00:00 AM -114.071218  51.101800
#
#       Cluster Labels
# 85                 1
# 86                 1
# 87                 1
# 88                 1
# 89                 1
# ...              ...
# 1844               1
# 1845               1
# 1846               1
# 1847               1
# 1848               1
#
# [206 rows x 9 columns]

# %%
calgary_merged.loc[calgary_merged['Cluster Labels'] == 2, calgary_merged.columns[[0] + list(range(1, calgary_merged.shape[1]))]]
# Out:
#                               Tradename                    Address  \
# 2     CHINE LEGENDARY HOT POT & NOODLES     8971 BONAVENTURE DR SE
# 3         MUCHO BURRITO FAIRMOUNT DRIVE  #130 9825 FAIRMOUNT DR SE
# 4                GOLDEN GATE RESTAURANT       #14 430 ACADIA DR SE
# 5                GOLDEN GATE RESTAURANT       #14 430 ACADIA DR SE
# 6                    A B C LIQUOR STORE       #24 430 ACADIA DR SE
# ...                                 ...                        ...
# 1980                         CARL'S JR.    #100 5211 MACLEOD TR SW
# 1981                     SHANGSHANGQIAN    #106 5211 MACLEOD TR SW
# 1982     BROWNS SOCIALHOUSE - BRITANNIA           5139 ELBOW DR SW
# 1983   BLUE OCEAN VIETNAMESE RESTAURANT    #105 5809 MACLEOD TR SW
# 1984               GRUMANS DELICATESSEN           5103 ELBOW DR SW
#
#                              License Type     Community            Status  \
# 2     ALCOHOL BEVERAGE SALES (RESTAURANT)        ACADIA  Renewal Licensed
# 3     ALCOHOL BEVERAGE SALES (RESTAURANT)        ACADIA  Renewal Licensed
# 4     ALCOHOL BEVERAGE SALES (RESTAURANT)        ACADIA  Renewal Licensed
# 5     ALCOHOL BEVERAGE SALES (RESTAURANT)        ACADIA  Renewal Licensed
# 6                            LIQUOR STORE        ACADIA  Renewal Licensed
# ...                                   ...           ...               ...
# 1980  ALCOHOL BEVERAGE SALES (RESTAURANT)  WINDSOR PARK  Renewal Licensed
# 1981  ALCOHOL BEVERAGE SALES (RESTAURANT)  WINDSOR PARK          Licensed
# 1982  ALCOHOL BEVERAGE SALES (RESTAURANT)  WINDSOR PARK  Renewal Licensed
# 1983  ALCOHOL BEVERAGE SALES (RESTAURANT)  WINDSOR PARK   Pending Renewal
# 1984  ALCOHOL BEVERAGE SALES (RESTAURANT)  WINDSOR PARK  Renewal Licensed
#
#                  Established   Longitude   Latitude  Cluster Labels
# 2     09/13/2017 12:00:00 AM -114.069514  50.973351               2
# 3     04/03/2019 12:00:00 AM -114.059242  50.964289               2
# 4     07/15/2013 12:00:00 AM -114.047913  50.969766               2
# 5     07/15/2013 12:00:00 AM -114.047913  50.969766               2
# 6     06/20/2007 12:00:00 AM -114.047913  50.969766               2
# ...                      ...         ...        ...             ...
# 1980  12/12/2016 12:00:00 AM -114.068729  51.008451               2
# 1981  10/17/2019 12:00:00 AM -114.069117  51.008146               2
# 1982  10/29/2014 12:00:00 AM -114.081725  51.007998               2
# 1983  11/09/2015 12:00:00 AM -114.072544  51.002000               2
# 1984  08/02/2017 12:00:00 AM -114.081683  51.008594               2
#
# [227 rows x 9 columns]

# %%
cluster_3=calgary_merged.loc[calgary_merged['Cluster Labels'] == 3, calgary_merged.columns[[0] + list(range(1, calgary_merged.shape[1]))]]
cluster_3
# Out:
#                                  Tradename                     Address  \
# 335              MAGIC BOWL CHINESE EATERY  #12 1215 LAKE SYLVAN DR SE
# 389      SOBEYS WESTERN CELLARS BRIDLEWOOD         #803 2335 162 AV SW
# 390                            LI-AO SUSHI         #231 2335 162 AV SW
# 391                BROTHER'S TASTE OF ASIA         #223 2335 162 AV SW
# 392            STAR LIQUOR & WINE BOUTIQUE  #20 2525 BRIDLECREST WY SW
# ...                                    ...                         ...
# 1996                  PATISSERIE DU SOLIEL    #309 2525 WOODVIEW DR SW
# 1997             WOODBINE B K LIQUOR STORE       #C 464 WOODBINE BV SW
# 1998     ACE LIQUOR DISCOUNTER AT WOODBINE    #204 2525 WOODVIEW DR SW
# 1999                 WOODPARK LIQUOR STORE      #14 523 WOODPARK BV SW
# 2000  CANYON MEADOWS GOLF AND COUNTRY CLUB           #A 12501 14 ST SW
#
#                              License Type        Community            Status  \
# 335   ALCOHOL BEVERAGE SALES (RESTAURANT)  BONAVISTA DOWNS  Renewal Licensed
# 389                          LIQUOR STORE       BRIDLEWOOD   Pending Renewal
# 390   ALCOHOL BEVERAGE SALES (RESTAURANT)       BRIDLEWOOD  Renewal Licensed
# 391   ALCOHOL BEVERAGE SALES (RESTAURANT)       BRIDLEWOOD  Renewal Licensed
# 392                          LIQUOR STORE       BRIDLEWOOD  Renewal Licensed
# ...                                   ...              ...               ...
# 1996  ALCOHOL BEVERAGE SALES (RESTAURANT)         WOODBINE  Renewal Licensed
# 1997                         LIQUOR STORE         WOODBINE  Renewal Licensed
# 1998                         LIQUOR STORE         WOODBINE   Pending Renewal
# 1999                         LIQUOR STORE        WOODLANDS  Renewal Licensed
# 2000  ALCOHOL BEVERAGE SALES (RESTAURANT)        WOODLANDS  Renewal Licensed
#
#                  Established   Longitude   Latitude  Cluster Labels
# 335   04/21/2003 12:00:00 AM -114.032358  50.942236               3
# 389   09/08/2003 12:00:00 AM -114.112970  50.906207               3
# 390   08/10/2011 12:00:00 AM -114.111723  50.905289               3
# 391   03/14/2011 12:00:00 AM -114.111903  50.905290               3
# 392   08/28/2014 12:00:00 AM -114.117654  50.900949               3
# ...                      ...         ...        ...             ...
# 1996  06/03/2010 12:00:00 AM -114.121133  50.940540               3
# 1997  03/30/2005 12:00:00 AM -114.133474  50.946462               3
# 1998  09/21/2004 12:00:00 AM -114.120083  50.940327               3
# 1999  06/04/2007 12:00:00 AM -114.109716  50.940752               3
# 2000  10/07/1994 12:00:00 AM -114.095957  50.941746               3
#
# [103 rows x 9 columns]

# %%
calgary_merged.loc[calgary_merged['Cluster Labels'] == 4, calgary_merged.columns[[0] + list(range(1, calgary_merged.shape[1]))]]
# Out:
#                                         Tradename                  Address  \
# 0                                ABLO (ABBEYDALE)             822 68 ST NE
# 1                             ABBEYDALE COMMUNITY      821 ABBEYDALE DR NE
# 27    CALGARY CO-OP WINES & SPIRITS - FOREST LAWN        #1A 3200 17 AV SE
# 28                                   LA BEER STOP       #115 3608 17 AV SE
# 29                    AMBASSADOR RESTAURANT & BAR           3504D 17 AV SE
# ...                                           ...                      ...
# 1959                                       PHO 36  #7 135 WHITEFIELD DR NE
# 1960                                       PHO 36  #7 135 WHITEFIELD DR NE
# 1961       WHITEHORN VILLAGE RETIREMENT COMMUNITY      #1000 5200 44 AV NE
# 1962                       WHITEHORN LIQUOR STORE         #9 4525 52 ST NE
# 1963                                ABBY'S LIQUOR  #9 5008 WHITEHORN DR NE
#
#                              License Type                     Community  \
# 0                            LIQUOR STORE                     ABBEYDALE
# 1     ALCOHOL BEVERAGE SALES (RESTAURANT)                     ABBEYDALE
# 27                           LIQUOR STORE  ALBERT PARK/RADISSON HEIGHTS
# 28                           LIQUOR STORE  ALBERT PARK/RADISSON HEIGHTS
# 29    ALCOHOL BEVERAGE SALES (RESTAURANT)  ALBERT PARK/RADISSON HEIGHTS
# ...                                   ...                           ...
# 1959  ALCOHOL BEVERAGE SALES (RESTAURANT)                     WHITEHORN
# 1960  ALCOHOL BEVERAGE SALES (RESTAURANT)                     WHITEHORN
# 1961  ALCOHOL BEVERAGE SALES (RESTAURANT)                     WHITEHORN
# 1962                         LIQUOR STORE                     WHITEHORN
# 1963                         LIQUOR STORE                     WHITEHORN
#
#                 Status             Established   Longitude   Latitude  \
# 0      Pending Renewal  08/21/2017 12:00:00 AM -113.934380  51.059158
# 1     Renewal Licensed  02/05/1999 12:00:00 AM -113.932329  51.059753
# 27    Renewal Licensed  10/20/2009 12:00:00 AM -113.989140  51.038891
# 28    Renewal Licensed  03/08/2004 12:00:00 AM -113.982770  51.038372
# 29    Renewal Licensed  07/02/2019 12:00:00 AM -113.984301  51.038157
# ...                ...                     ...         ...        ...
# 1959  Renewal Licensed  12/06/2013 12:00:00 AM -113.980673  51.087927
# 1960  Renewal Licensed  12/06/2013 12:00:00 AM -113.980673  51.087927
# 1961   Pending Renewal  10/15/2002 12:00:00 AM -113.959776  51.092676
# 1962   Pending Renewal  03/08/2002 12:00:00 AM -113.959226  51.091792
# 1963  Renewal Licensed  11/01/2010 12:00:00 AM -113.962016  51.086207
#
#       Cluster Labels
# 0                  4
# 1                  4
# 27                 4
# 28                 4
# 29                 4
# ...              ...
# 1959               4
# 1960               4
# 1961               4
# 1962               4
# 1963               4
#
# [292 rows x 9 columns]

# %%
cluster_5 = calgary_merged.loc[calgary_merged['Cluster Labels'] == 5, calgary_merged.columns[[0] + list(range(1, calgary_merged.shape[1]))]]
cluster_5
# Out:
#                                Tradename               Address  \
# 38    CROWFOOT WINE & SPIRITS - ALTADORE    #103 3505 14 ST SW
# 42              LIQUOR DEPOT AT ALTADORE         3504 19 ST SW
# 43            MARDA LOOP BREWING COMPANY         3523 18 ST SW
# 44                   ZYN THE WINE MARKET    #100 1543 17 AV SE
# 45               CRAZY HORSE BAR & GRILL   #1 4068 OGDEN RD SE
# ...                                  ...                   ...
# 1990                  TRANSCANADA LIQUOR          428 16 AV NE
# 1991          EASTERN FORTUNE RESTAURANT          416 16 AV NE
# 1992   CAREWEST DR VERNON FANNING CENTRE          722 16 AV NE
# 1993                   BUZZ BUDDY LIQUOR  2418A EDMONTON TR NE
# 1994             WINSTON GOLF CLUB (THE)          2502 6 ST NE
#
#                              License Type                  Community  \
# 38                           LIQUOR STORE                   ALTADORE
# 42                           LIQUOR STORE                   ALTADORE
# 43    ALCOHOL BEVERAGE SALES (RESTAURANT)                   ALTADORE
# 44                           LIQUOR STORE           ALYTH/BONNYBROOK
# 45    ALCOHOL BEVERAGE SALES (RESTAURANT)           ALYTH/BONNYBROOK
# ...                                   ...                        ...
# 1990                         LIQUOR STORE  WINSTON HEIGHTS/MOUNTVIEW
# 1991  ALCOHOL BEVERAGE SALES (RESTAURANT)  WINSTON HEIGHTS/MOUNTVIEW
# 1992  ALCOHOL BEVERAGE SALES (RESTAURANT)  WINSTON HEIGHTS/MOUNTVIEW
# 1993                         LIQUOR STORE  WINSTON HEIGHTS/MOUNTVIEW
# 1994  ALCOHOL BEVERAGE SALES (RESTAURANT)  WINSTON HEIGHTS/MOUNTVIEW
#
#                 Status             Established   Longitude   Latitude  \
# 38    Renewal Licensed  04/20/2015 12:00:00 AM -114.095096  51.022851
# 42    Renewal Licensed  06/06/2006 12:00:00 AM -114.106115  51.022974
# 43    Renewal Licensed  05/07/2018 12:00:00 AM -114.105086  51.022274
# 44     Pending Renewal  11/03/2008 12:00:00 AM -114.027838  51.036524
# 45    Renewal Licensed  12/11/2018 12:00:00 AM -114.023237  51.018837
# ...                ...                     ...         ...        ...
# 1990  Renewal Licensed  12/13/2001 12:00:00 AM -114.054768  51.067241
# 1991  Renewal Licensed  08/07/2015 12:00:00 AM -114.055134  51.067140
# 1992  Renewal Licensed  03/09/1998 12:00:00 AM -114.045537  51.067280
# 1993  Renewal Licensed  11/03/2015 12:00:00 AM -114.055881  51.074076
# 1994  Renewal Licensed  12/16/2016 12:00:00 AM -114.044248  51.075195
#
#       Cluster Labels
# 38                 5
# 42                 5
# 43                 5
# 44                 5
# 45                 5
# ...              ...
# 1990               5
# 1991               5
# 1992               5
# 1993               5
# 1994               5
#
# [756 rows x 9 columns]

# %%
calgary_merged.loc[calgary_merged['Cluster Labels'] == 6, calgary_merged.columns[[0] + list(range(1, calgary_merged.shape[1]))]]
# Out:
#                                      Tradename                        Address  \
# 83         AUBURN HEIGHTS RETIREMENT RESIDENCE            21 AUBURN BAY ST SE
# 84    CO-OP WINE SPIRITS BEER #26 - AUBURN BAY  #310 100 AUBURN MEADOWS DR SE
# 574        ACE LIQUOR DISCOUNTER AT COPPERPOND      #209 151 COPPERPOND BV SE
# 575       ACE LIQUOR DISCOUNTER AT COPPERFIELD      #107 10 COPPERSTONE ST SE
# 576                STAR LIQUOR & WINE BOUTIQUE        #242 15566 MCIVOR BV SE
# ...                                        ...                            ...
# 1633                             MOROCCAN TENT            #210 11566 24 ST SE
# 1634                             MOROCCAN TENT            #210 11566 24 ST SE
# 1635                     RICKY'S ALL DAY GRILL            #658 11520 24 ST SE
# 1636                              RALLY POINTE                 11511 35 ST SE
# 1637                       CALGARY RUGBY UNION             9025 SHEPARD RD SE
#
#                              License Type           Community  \
# 83    ALCOHOL BEVERAGE SALES (RESTAURANT)          AUBURN BAY
# 84                           LIQUOR STORE          AUBURN BAY
# 574                          LIQUOR STORE         COPPERFIELD
# 575                          LIQUOR STORE         COPPERFIELD
# 576                          LIQUOR STORE         COPPERFIELD
# ...                                   ...                 ...
# 1633  ALCOHOL BEVERAGE SALES (RESTAURANT)  SHEPARD INDUSTRIAL
# 1634  ALCOHOL BEVERAGE SALES (RESTAURANT)  SHEPARD INDUSTRIAL
# 1635  ALCOHOL BEVERAGE SALES (RESTAURANT)  SHEPARD INDUSTRIAL
# 1636  ALCOHOL BEVERAGE SALES (RESTAURANT)  SHEPARD INDUSTRIAL
# 1637  ALCOHOL BEVERAGE SALES (RESTAURANT)  SHEPARD INDUSTRIAL
#
#                 Status             Established   Longitude   Latitude  \
# 83    Renewal Licensed  02/08/2018 12:00:00 AM -113.950619  50.884219
# 84     Pending Renewal  09/21/2016 12:00:00 AM -113.945533  50.894710
# 574   Renewal Licensed  06/07/2019 12:00:00 AM -113.932166  50.924095
# 575   Renewal Licensed  06/07/2019 12:00:00 AM -113.933652  50.915757
# 576    Pending Renewal  07/28/2005 12:00:00 AM -113.950129  50.912690
# ...                ...                     ...         ...        ...
# 1633  Renewal Licensed  04/15/2019 12:00:00 AM -114.001743  50.950990
# 1634  Renewal Licensed  04/15/2019 12:00:00 AM -114.001743  50.950990
# 1635  Renewal Licensed  09/19/2017 12:00:00 AM -114.000512  50.952666
# 1636  Renewal Licensed  01/10/2007 12:00:00 AM -113.985855  50.947604
# 1637  Renewal Licensed  07/23/1999 12:00:00 AM -113.991739  50.972289
#
#       Cluster Labels
# 83                 6
# 84                 6
# 574                6
# 575                6
# 576                6
# ...              ...
# 1633               6
# 1634               6
# 1635               6
# 1636               6
# 1637               6
#
# [109 rows x 9 columns]

# %%
cluster_7=calgary_merged.loc[calgary_merged['Cluster Labels'] == 7, calgary_merged.columns[[0] + list(range(1, calgary_merged.shape[1]))]]
cluster_7
# Out:
#                                          Tradename  \
# 74                    DINER DELUXE - ASPEN LANDING
# 75                                   MUCHO BURRITO
# 76                                          KABUKU
# 77                               AMICA ASPEN WOODS
# 78                               ALLORA RESTAURANT
# ...                                            ...
# 1937                              NIRVANA NAIL BAR
# 1938  CALGARY CO-OP WINES & SPIRITS - WEST SPRINGS
# 1939              BOARDWALK FRIES, BURGERS, SHAKES
# 1940       722 WORLD BIER HAUS RESTAURANT & LOUNGE
# 1941                                     HUB (THE)
#
#                          Address                         License Type  \
# 74     #104 350 ASPEN GLEN LD SW  ALCOHOL BEVERAGE SALES (RESTAURANT)
# 75     #132 306 ASPEN GLEN LD SW  ALCOHOL BEVERAGE SALES (RESTAURANT)
# 76    #2136 10 ASPEN STONE BV SW  ALCOHOL BEVERAGE SALES (RESTAURANT)
# 77           10 ASPENSHIRE DR SW  ALCOHOL BEVERAGE SALES (RESTAURANT)
# 78     #114 326 ASPEN GLEN LD SW  ALCOHOL BEVERAGE SALES (RESTAURANT)
# ...                          ...                                  ...
# 1937          #3001 873 85 ST SW  ALCOHOL BEVERAGE SALES (RESTAURANT)
# 1938           #600 917 85 ST SW                         LIQUOR STORE
# 1939          #1005 873 85 ST SW  ALCOHOL BEVERAGE SALES (RESTAURANT)
# 1940           #601 722 85 ST SW  ALCOHOL BEVERAGE SALES (RESTAURANT)
# 1941          #10 4623 BOW TR SW  ALCOHOL BEVERAGE SALES (RESTAURANT)
#
#          Community            Status             Established   Longitude  \
# 74     ASPEN WOODS  Renewal Licensed  02/24/2014 12:00:00 AM -114.209141
# 75     ASPEN WOODS  Renewal Licensed  03/06/2012 12:00:00 AM -114.207776
# 76     ASPEN WOODS  Renewal Licensed  12/11/2013 12:00:00 AM -114.212613
# 77     ASPEN WOODS  Renewal Licensed  08/01/2013 12:00:00 AM -114.212292
# 78     ASPEN WOODS  Renewal Licensed  05/18/2010 12:00:00 AM -114.208549
# ...            ...               ...                     ...         ...
# 1937  WEST SPRINGS  Renewal Licensed  12/16/2016 12:00:00 AM -114.212448
# 1938  WEST SPRINGS   Pending Renewal  10/20/2009 12:00:00 AM -114.211434
# 1939  WEST SPRINGS  Renewal Licensed  02/22/2017 12:00:00 AM -114.211585
# 1940  WEST SPRINGS  Renewal Licensed  03/06/2015 12:00:00 AM -114.209675
# 1941      WESTGATE   Pending Renewal  09/01/2017 12:00:00 AM -114.153745
#
#        Latitude  Cluster Labels
# 74    51.039819               7
# 75    51.039102               7
# 76    51.041447               7
# 77    51.048945               7
# 78    51.039363               7
# ...         ...             ...
# 1937  51.059875               7
# 1938  51.058033               7
# 1939  51.059900               7
# 1940  51.066158               7
# 1941  51.048660               7
#
# [188 rows x 9 columns]

# %%
# Cluster 5 latitude and longitude values
latitude = 51.04
longitude = -114.07

# define Calgary map 
Calgary_map1 = folium.Map(location=[latitude, longitude], zoom_start=12)

# add markers to map
for lat, lng, label in zip(cluster_5['Latitude'], cluster_5['Longitude'], cluster_5['Community']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(Calgary_map1)  
    
Calgary_map1
# display Calgary map
Calgary_map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Cluster 3 latitude and longitude values
latitude = 51.04
longitude = -114.07

# define Calgary map 
Calgary_map2 = folium.Map(location=[latitude, longitude], zoom_start=12)

# add markers to map
for lat, lng, label in zip(cluster_3['Latitude'], cluster_3['Longitude'], cluster_3['Community']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(Calgary_map2)  
    
Calgary_map2
# display Calgary map
Calgary_map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
